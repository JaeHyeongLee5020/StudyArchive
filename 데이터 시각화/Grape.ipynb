# %%
import matplotlib.ptplot as plt
plt.plot(10,20,30,40)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9792/3457307227.py in <module>
# ----> 1 import matplotlib.ptplot as plt
#       2 plt.plot(10,20,30,40)
#       3 plt.show()
#
# ModuleNotFoundError: No module named 'matplotlib.ptplot'

# %%
import matplotlib.ptplot as plt
plt.plot([10,20,30,40])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9792/538897636.py in <module>
# ----> 1 import matplotlib.ptplot as plt
#       2 plt.plot([10,20,30,40])
#       3 plt.show()
#
# ModuleNotFoundError: No module named 'matplotlib.ptplot'

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[12,43,25,15])
plt.show()

# %%
import matplotlib.ptplot as plt
plt.title('plotting')
plt.plot([10,20,30,40])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9792/102777475.py in <module>
# ----> 1 import matplotlib.ptplot as plt
#       2 plt.title('plotting')
#       3 plt.plot([10,20,30,40])
#       4 plt.show()
#
# ModuleNotFoundError: No module named 'matplotlib.ptplot'

# %%
import matplotlib.ptplot as plt
plt.plot(10,20,30,40)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9792/3457307227.py in <module>
# ----> 1 import matplotlib.ptplot as plt
#       2 plt.plot(10,20,30,40)
#       3 plt.show()
#
# ModuleNotFoundError: No module named 'matplotlib.ptplot'

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[12,43,25,15])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun Gothic')
plt.title('연속해서 점찍기')
plt.plot([10, 20, 30, 40])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title('legend')
plt.plot([10, 20, 30, 40], lable='asc')
plt.plot([40, 30, 20, 10], lable='desc')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9792/90542113.py in <module>
#       1 import matplotlib.pyplot as plt
#       2 plt.title('legend')
# ----> 3 plt.plot([10, 20, 30, 40], lable='asc')
#       4 plt.plot([40, 30, 20, 10], lable='desc')
#       5 plt.legend()
#
# C:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
# ...

# %%
import matplotlib.pyplot as plt
plt.title('legend')
plt.plot([10, 20, 30, 40], lable='ascending')
plt.plot([40, 30, 20, 10], lable='descending')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9792/3007446547.py in <module>
#       1 import matplotlib.pyplot as plt
#       2 plt.title('legend')
# ----> 3 plt.plot([10, 20, 30, 40], lable='ascending')
#       4 plt.plot([40, 30, 20, 10], lable='descending')
#       5 plt.legend()
#
# C:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
# ...

# %%
import matplotlib.pyplot as plt
plt.title('legend')
plt.plot([10, 20, 30, 40], lable='ascending')
plt.plot([40, 30, 20, 10], lable='descending')
plt.legend(loc = 6)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9792/1731490177.py in <module>
#       1 import matplotlib.pyplot as plt
#       2 plt.title('legend')
# ----> 3 plt.plot([10, 20, 30, 40], lable='ascending')
#       4 plt.plot([40, 30, 20, 10], lable='descending')
#       5 plt.legend(loc = 6)
#
# C:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
# ...

# %%
import matplotlib.pyplot as plt
plt.title('color')
plt.plot([10, 20, 30, 40], color = 'skyblue', lable = 'skybule')
plt.plot([40, 30, 20, 10], 'pink', lable = 'pink')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9792/1937106369.py in <module>
#       1 import matplotlib.pyplot as plt
#       2 plt.title('color')
# ----> 3 plt.plot([10, 20, 30, 40], color = 'skyblue', lable = 'skybule')
#       4 plt.plot([40, 30, 20, 10], 'pink', lable = 'pink')
#       5 plt.legend()
#
# C:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
# ...

# %%
import matplotlib.pyplot as plt

plt.title('color')
plt.plot([10, 20, 30, 40], color='skyblue', label='skyblue')
plt.plot([40, 30, 20, 10], 'pink', label='pink')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title('marker')
plt.plot([10, 20, 30, 40], 'r.', label='circle')
plt.plot([40, 30, 20, 10], 'g^', label='triangle up')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title('marker')
plt.plot([10, 20, 30, 40],color='r',label='dashed',ls='--' ,'r.', label='circle')
plt.plot([40, 30, 20, 10], 'g^', label='triangle up')
plt.legend()
plt.show()
# Out:
#   File "C:\Users\Admin\AppData\Local\Temp/ipykernel_9792/26517565.py", line 3
#     plt.plot([10, 20, 30, 40],color='r',label='dashed',ls='--' ,'r.', label='circle')
#                                                                                     ^
# SyntaxError: positional argument follows keyword argument

# %%
import matplotlib.pyplot as plt

plt.title('marker')
plt.plot([10, 20, 30, 40], color='r', ls='--', label='dashed')
plt.plot([10, 20, 30, 40], 'r.', label='circle')
plt.plot([40, 30, 20, 10], 'g^', label='triangle up')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('marker')
plt.plot([10, 20, 30, 40], color='r', ls='--', label='dashed')
plt.plot([10, 20, 30, 40], 'r.', label='circle')
plt.plot([40, 30, 20, 10],color='g',ls=':',label='dotted')
plt.plot([40, 30, 20, 10], 'g^', label='triangle up')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('marker')
plt.plot([10, 20, 30, 40], color='g', ls=':', label='dotted')
plt.plot([10, 20, 30, 40], 'g.', label='circle')
plt.plot([40, 30, 20, 10],color='r',ls='-.',label='dashdotted')
plt.plot([40, 30, 20, 10], 'r^', label='triangle up')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('marker')
plt.plot([10, 20, 30, 40], color='g', ls='-.', label='dashdotted')
plt.plot([10, 20, 30, 40], 'g.', label='circle')
plt.plot([40, 30, 20, 10],color='r',ls=':',label='dotted')
plt.plot([40, 30, 20, 10], 'r^', label='triangle up')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('marker')
plt.plot([10, 20, 30, 40], color='g', ls='-.', label='dashdotted')
plt.plot([10, 20, 30, 40], 'g.', label='circle')
plt.plot([40, 30, 20, 10],color='r',ls=':',label='dotted')
plt.plot([40, 30, 20, 10], 'r^', label='triangle up')
plt.legend()
plt.show()
